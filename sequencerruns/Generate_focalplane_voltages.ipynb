# %% [markdown]
# This script will change the REB CCD voltages specified in the /etc/ccs folder

# %%
PclkH=3.3
PclkL=-7.0
SclkH=3.9
SclkL=-5.4
OG=-3.4
OD=23.4
RD=11.6
RGH=6.1
RGL=-4.0

# %%
fpdir="/home/ccd/ccs/etc/"
propertiesfile=fpdir+"FocalPlane_ucd_Rafts.properties"
limitsfile=fpdir+"FocalPlane_ucd_RaftsLimits.properties"

# %%
properties='''R21/Reb0/Bias0/csGate = 0
R21/Reb0/Bias0/csGateP = 1.0
R21/Reb0/Bias0/gd = 0
R21/Reb0/Bias0/gdP = 26.0
R21/Reb0/Bias0/od = 0
R21/Reb0/Bias0/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb0/Bias0/og = 0
R21/Reb0/Bias0/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb0/Bias0/ogSh = 0
R21/Reb0/Bias0/rd = 0
R21/Reb0/Bias0/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb0/Bias1/csGate = 0
R21/Reb0/Bias1/csGateP = 1.0
R21/Reb0/Bias1/gd = 0
R21/Reb0/Bias1/gdP = 26.0
R21/Reb0/Bias1/od = 0
R21/Reb0/Bias1/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb0/Bias1/og = 0
R21/Reb0/Bias1/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb0/Bias1/ogSh = 0
R21/Reb0/Bias1/rd = 0
R21/Reb0/Bias1/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb0/Bias2/csGate = 0
R21/Reb0/Bias2/csGateP = 1.0
R21/Reb0/Bias2/gd = 0
R21/Reb0/Bias2/gdP = 26.0
R21/Reb0/Bias2/od = 0
R21/Reb0/Bias2/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb0/Bias2/og = 0
R21/Reb0/Bias2/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb0/Bias2/ogSh = 0
R21/Reb0/Bias2/rd = 0
R21/Reb0/Bias2/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb0/DAC/csGate = [0,0,0]
R21/Reb0/DAC/pclkHigh = 0
R21/Reb0/DAC/pclkHighP = '''+'{0:.2f}'.format(PclkH)+'''
R21/Reb0/DAC/pclkHighSh = 0
R21/Reb0/DAC/pclkLow = 0
R21/Reb0/DAC/pclkLowP = '''+'{0:.2f}'.format(PclkL)+'''
R21/Reb0/DAC/pclkLowSh = 0
R21/Reb0/DAC/rgHigh = 0
R21/Reb0/DAC/rgHighP = '''+'{0:.2f}'.format(RGH)+'''
R21/Reb0/DAC/rgHighSh = 0
R21/Reb0/DAC/rgLow = 0
R21/Reb0/DAC/rgLowP = '''+'{0:.2f}'.format(RGL)+'''
R21/Reb0/DAC/rgLowSh = 0
R21/Reb0/DAC/sclkHigh = 0
R21/Reb0/DAC/sclkHighP = '''+'{0:.2f}'.format(SclkH)+'''
R21/Reb0/DAC/sclkHighSh = 0
R21/Reb0/DAC/sclkLow = 0
R21/Reb0/DAC/sclkLowP = '''+'{0:.2f}'.format(SclkL)+'''
R21/Reb0/DAC/sclkLowSh = 0
R21/Reb0/S00/ASPIC0/af1 = 0
R21/Reb0/S00/ASPIC0/clamp = 0
R21/Reb0/S00/ASPIC0/gain = 0
R21/Reb0/S00/ASPIC0/rc = 14
R21/Reb0/S00/ASPIC0/tm = 0
R21/Reb0/S00/ASPIC1/af1 = 0
R21/Reb0/S00/ASPIC1/clamp = 0
R21/Reb0/S00/ASPIC1/gain = 0
R21/Reb0/S00/ASPIC1/rc = 14
R21/Reb0/S00/ASPIC1/tm = 0
R21/Reb0/S01/ASPIC0/af1 = 0
R21/Reb0/S01/ASPIC0/clamp = 0
R21/Reb0/S01/ASPIC0/gain = 0
R21/Reb0/S01/ASPIC0/rc = 14
R21/Reb0/S01/ASPIC0/tm = 0
R21/Reb0/S01/ASPIC1/af1 = 0
R21/Reb0/S01/ASPIC1/clamp = 0
R21/Reb0/S01/ASPIC1/gain = 0
R21/Reb0/S01/ASPIC1/rc = 14
R21/Reb0/S01/ASPIC1/tm = 0
R21/Reb0/S02/ASPIC0/af1 = 0
R21/Reb0/S02/ASPIC0/clamp = 0
R21/Reb0/S02/ASPIC0/gain = 0
R21/Reb0/S02/ASPIC0/rc = 14
R21/Reb0/S02/ASPIC0/tm = 0
R21/Reb0/S02/ASPIC1/af1 = 0
R21/Reb0/S02/ASPIC1/clamp = 0
R21/Reb0/S02/ASPIC1/gain = 0
R21/Reb0/S02/ASPIC1/rc = 14
R21/Reb0/S02/ASPIC1/tm = 0
R21/Reb0/disableRTDHardwareCheck = true
R21/Reb0/serialNum = -1
R21/Reb0/useScienceCCD = false
R21/Reb1/Bias0/csGate = 0
R21/Reb1/Bias0/csGateP = 1.0
R21/Reb1/Bias0/gd = 0
R21/Reb1/Bias0/gdP = 26.0
R21/Reb1/Bias0/od = 0
R21/Reb1/Bias0/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb1/Bias0/og = 0
R21/Reb1/Bias0/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb1/Bias0/ogSh = 0
R21/Reb1/Bias0/rd = 0
R21/Reb1/Bias0/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb1/Bias1/csGate = 0
R21/Reb1/Bias1/csGateP = 1.0
R21/Reb1/Bias1/gd = 0
R21/Reb1/Bias1/gdP = 26.0
R21/Reb1/Bias1/od = 0
R21/Reb1/Bias1/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb1/Bias1/og = 0
R21/Reb1/Bias1/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb1/Bias1/ogSh = 0
R21/Reb1/Bias1/rd = 0
R21/Reb1/Bias1/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb1/Bias2/csGate = 0
R21/Reb1/Bias2/csGateP = 1.0
R21/Reb1/Bias2/gd = 0
R21/Reb1/Bias2/gdP = 26.0
R21/Reb1/Bias2/od = 0
R21/Reb1/Bias2/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb1/Bias2/og = 0
R21/Reb1/Bias2/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb1/Bias2/ogSh = 0
R21/Reb1/Bias2/rd = 0
R21/Reb1/Bias2/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb1/DAC/csGate = [0,0,0]
R21/Reb1/DAC/pclkHigh = 0
R21/Reb1/DAC/pclkHighP = '''+'{0:.2f}'.format(PclkH)+'''
R21/Reb1/DAC/pclkHighSh = 0
R21/Reb1/DAC/pclkLow = 0
R21/Reb1/DAC/pclkLowP = '''+'{0:.2f}'.format(PclkL)+'''
R21/Reb1/DAC/pclkLowSh = 0
R21/Reb1/DAC/rgHigh = 0
R21/Reb1/DAC/rgHighP = '''+'{0:.2f}'.format(RGH)+'''
R21/Reb1/DAC/rgHighSh = 0
R21/Reb1/DAC/rgLow = 0
R21/Reb1/DAC/rgLowP = '''+'{0:.2f}'.format(RGL)+'''
R21/Reb1/DAC/rgLowSh = 0
R21/Reb1/DAC/sclkHigh = 0
R21/Reb1/DAC/sclkHighP = '''+'{0:.2f}'.format(SclkH)+'''
R21/Reb1/DAC/sclkHighSh = 0
R21/Reb1/DAC/sclkLow = 0
R21/Reb1/DAC/sclkLowP = '''+'{0:.2f}'.format(SclkL)+'''
R21/Reb1/DAC/sclkLowSh = 0
R21/Reb1/S10/ASPIC0/af1 = 0
R21/Reb1/S10/ASPIC0/clamp = 0
R21/Reb1/S10/ASPIC0/gain = 0
R21/Reb1/S10/ASPIC0/rc = 14
R21/Reb1/S10/ASPIC0/tm = 0
R21/Reb1/S10/ASPIC1/af1 = 0
R21/Reb1/S10/ASPIC1/clamp = 0
R21/Reb1/S10/ASPIC1/gain = 0
R21/Reb1/S10/ASPIC1/rc = 14
R21/Reb1/S10/ASPIC1/tm = 0
R21/Reb1/S11/ASPIC0/af1 = 0
R21/Reb1/S11/ASPIC0/clamp = 0
R21/Reb1/S11/ASPIC0/gain = 0
R21/Reb1/S11/ASPIC0/rc = 14
R21/Reb1/S11/ASPIC0/tm = 0
R21/Reb1/S11/ASPIC1/af1 = 0
R21/Reb1/S11/ASPIC1/clamp = 0
R21/Reb1/S11/ASPIC1/gain = 0
R21/Reb1/S11/ASPIC1/rc = 14
R21/Reb1/S11/ASPIC1/tm = 0
R21/Reb1/S12/ASPIC0/af1 = 0
R21/Reb1/S12/ASPIC0/clamp = 0
R21/Reb1/S12/ASPIC0/gain = 0
R21/Reb1/S12/ASPIC0/rc = 14
R21/Reb1/S12/ASPIC0/tm = 0
R21/Reb1/S12/ASPIC1/af1 = 0
R21/Reb1/S12/ASPIC1/clamp = 0
R21/Reb1/S12/ASPIC1/gain = 0
R21/Reb1/S12/ASPIC1/rc = 14
R21/Reb1/S12/ASPIC1/tm = 0
R21/Reb1/disableRTDHardwareCheck = true
R21/Reb1/serialNum = -1
R21/Reb1/useScienceCCD = false
R21/Reb2/Bias0/csGate = 0
R21/Reb2/Bias0/csGateP = 1.0
R21/Reb2/Bias0/gd = 0
R21/Reb2/Bias0/gdP = 26.0
R21/Reb2/Bias0/od = 0
R21/Reb2/Bias0/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb2/Bias0/og = 0
R21/Reb2/Bias0/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb2/Bias0/ogSh = 0
R21/Reb2/Bias0/rd = 0
R21/Reb2/Bias0/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb2/Bias1/csGate = 0
R21/Reb2/Bias1/csGateP = 1.0
R21/Reb2/Bias1/gd = 0
R21/Reb2/Bias1/gdP = 26.0
R21/Reb2/Bias1/od = 0
R21/Reb2/Bias1/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb2/Bias1/og = 0
R21/Reb2/Bias1/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb2/Bias1/ogSh = 0
R21/Reb2/Bias1/rd = 0
R21/Reb2/Bias1/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb2/Bias2/csGate = 0
R21/Reb2/Bias2/csGateP = 1.0
R21/Reb2/Bias2/gd = 0
R21/Reb2/Bias2/gdP = 26.0
R21/Reb2/Bias2/od = 0
R21/Reb2/Bias2/odP = '''+'{0:.2f}'.format(OD)+'''
R21/Reb2/Bias2/og = 0
R21/Reb2/Bias2/ogP = '''+'{0:.2f}'.format(OG)+'''
R21/Reb2/Bias2/ogSh = 0
R21/Reb2/Bias2/rd = 0
R21/Reb2/Bias2/rdP = '''+'{0:.2f}'.format(RD)+'''
R21/Reb2/DAC/csGate = [0,0,0]
R21/Reb2/DAC/pclkHigh = 0
R21/Reb2/DAC/pclkHighP = '''+'{0:.2f}'.format(PclkH)+'''
R21/Reb2/DAC/pclkHighSh = 0
R21/Reb2/DAC/pclkLow = 0
R21/Reb2/DAC/pclkLowP = '''+'{0:.2f}'.format(PclkL)+'''
R21/Reb2/DAC/pclkLowSh = 0
R21/Reb2/DAC/rgHigh = 0
R21/Reb2/DAC/rgHighP = '''+'{0:.2f}'.format(RGH)+'''
R21/Reb2/DAC/rgHighSh = 0
R21/Reb2/DAC/rgLow = 0
R21/Reb2/DAC/rgLowP = '''+'{0:.2f}'.format(RGL)+'''
R21/Reb2/DAC/rgLowSh = 0
R21/Reb2/DAC/sclkHigh = 0
R21/Reb2/DAC/sclkHighP = '''+'{0:.2f}'.format(SclkH)+'''
R21/Reb2/DAC/sclkHighSh = 0
R21/Reb2/DAC/sclkLow = 0
R21/Reb2/DAC/sclkLowP = '''+'{0:.2f}'.format(SclkL)+'''
R21/Reb2/DAC/sclkLowSh = 0
R21/Reb2/S20/ASPIC0/af1 = 0
R21/Reb2/S20/ASPIC0/clamp = 0
R21/Reb2/S20/ASPIC0/gain = 0
R21/Reb2/S20/ASPIC0/rc = 14
R21/Reb2/S20/ASPIC0/tm = 0
R21/Reb2/S20/ASPIC1/af1 = 0
R21/Reb2/S20/ASPIC1/clamp = 0
R21/Reb2/S20/ASPIC1/gain = 0
R21/Reb2/S20/ASPIC1/rc = 14
R21/Reb2/S20/ASPIC1/tm = 0
R21/Reb2/S21/ASPIC0/af1 = 0
R21/Reb2/S21/ASPIC0/clamp = 0
R21/Reb2/S21/ASPIC0/gain = 0
R21/Reb2/S21/ASPIC0/rc = 14
R21/Reb2/S21/ASPIC0/tm = 0
R21/Reb2/S21/ASPIC1/af1 = 0
R21/Reb2/S21/ASPIC1/clamp = 0
R21/Reb2/S21/ASPIC1/gain = 0
R21/Reb2/S21/ASPIC1/rc = 14
R21/Reb2/S21/ASPIC1/tm = 0
R21/Reb2/S22/ASPIC0/af1 = 0
R21/Reb2/S22/ASPIC0/clamp = 0
R21/Reb2/S22/ASPIC0/gain = 0
R21/Reb2/S22/ASPIC0/rc = 14
R21/Reb2/S22/ASPIC0/tm = 0
R21/Reb2/S22/ASPIC1/af1 = 0
R21/Reb2/S22/ASPIC1/clamp = 0
R21/Reb2/S22/ASPIC1/gain = 0
R21/Reb2/S22/ASPIC1/rc = 14
R21/Reb2/S22/ASPIC1/tm = 0
R21/Reb2/disableRTDHardwareCheck = true
R21/Reb2/serialNum = -1
R21/Reb2/useScienceCCD = false
R22/Reb0/disableRTDHardwareCheck = true
R22/Reb0/serialNum=-1
R22/Reb0/Bias0/csGate=0
R22/Reb0/Bias0/csGateP=1.0
R22/Reb0/Bias0/gd=0
R22/Reb0/Bias0/gdP = 26.0
R22/Reb0/Bias0/od=0
R22/Reb0/Bias0/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb0/Bias0/og=0
R22/Reb0/Bias0/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb0/Bias0/ogSh=0
R22/Reb0/Bias0/rd=0
R22/Reb0/Bias0/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb0/Bias1/csGate=0
R22/Reb0/Bias1/csGateP=1.0
R22/Reb0/Bias1/gd=0
R22/Reb0/Bias1/gdP = 26.0
R22/Reb0/Bias1/od=0
R22/Reb0/Bias1/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb0/Bias1/og=0
R22/Reb0/Bias1/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb0/Bias1/ogSh=0
R22/Reb0/Bias1/rd=0
R22/Reb0/Bias1/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb0/Bias2/csGate=0
R22/Reb0/Bias2/csGateP=1.0
R22/Reb0/Bias2/gd=0
R22/Reb0/Bias2/gdP = 26.0
R22/Reb0/Bias2/od=0
R22/Reb0/Bias2/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb0/Bias2/og=0
R22/Reb0/Bias2/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb0/Bias2/ogSh=0
R22/Reb0/Bias2/rd=0
R22/Reb0/Bias2/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb0/DAC/csGate=[0,0,0]
R22/Reb0/DAC/pclkHigh=0
R22/Reb0/DAC/pclkHighP = '''+'{0:.2f}'.format(PclkH)+'''
R22/Reb0/DAC/pclkHighSh=0
R22/Reb0/DAC/pclkLow=0
R22/Reb0/DAC/pclkLowP = '''+'{0:.2f}'.format(PclkL)+'''
R22/Reb0/DAC/pclkLowSh=0
R22/Reb0/DAC/rgHigh=0
R22/Reb0/DAC/rgHighP = '''+'{0:.2f}'.format(RGH)+'''
R22/Reb0/DAC/rgHighSh=0
R22/Reb0/DAC/rgLow=0
R22/Reb0/DAC/rgLowP = '''+'{0:.2f}'.format(RGL)+'''
R22/Reb0/DAC/rgLowSh=0
R22/Reb0/DAC/sclkHigh=0
R22/Reb0/DAC/sclkHighP = '''+'{0:.2f}'.format(SclkH)+'''
R22/Reb0/DAC/sclkHighSh=0
R22/Reb0/DAC/sclkLow=0
R22/Reb0/DAC/sclkLowP = '''+'{0:.2f}'.format(SclkL)+'''
R22/Reb0/DAC/sclkLowSh=0
R22/Reb0/S00/ASPIC0/af1=0
R22/Reb0/S00/ASPIC0/clamp=0
R22/Reb0/S00/ASPIC0/gain=0
R22/Reb0/S00/ASPIC0/rc=14
R22/Reb0/S00/ASPIC0/tm=0
R22/Reb0/S00/ASPIC1/af1=0
R22/Reb0/S00/ASPIC1/clamp=0
R22/Reb0/S00/ASPIC1/gain=0
R22/Reb0/S00/ASPIC1/rc=14
R22/Reb0/S00/ASPIC1/tm=0
R22/Reb0/S01/ASPIC0/af1=0
R22/Reb0/S01/ASPIC0/clamp=0
R22/Reb0/S01/ASPIC0/gain=0
R22/Reb0/S01/ASPIC0/rc=14
R22/Reb0/S01/ASPIC0/tm=0
R22/Reb0/S01/ASPIC1/af1=0
R22/Reb0/S01/ASPIC1/clamp=0
R22/Reb0/S01/ASPIC1/gain=0
R22/Reb0/S01/ASPIC1/rc=14
R22/Reb0/S01/ASPIC1/tm=0
R22/Reb0/S02/ASPIC0/af1=0
R22/Reb0/S02/ASPIC0/clamp=0
R22/Reb0/S02/ASPIC0/gain=0
R22/Reb0/S02/ASPIC0/rc=14
R22/Reb0/S02/ASPIC0/tm=0
R22/Reb0/S02/ASPIC1/af1=0
R22/Reb0/S02/ASPIC1/clamp=0
R22/Reb0/S02/ASPIC1/gain=0
R22/Reb0/S02/ASPIC1/rc=14
R22/Reb0/S02/ASPIC1/tm=0
R22/Reb1/disableRTDHardwareCheck=true
R22/Reb1/serialNum=-1
R22/Reb1/Bias0/csGate=0
R22/Reb1/Bias0/csGateP=1.0
R22/Reb1/Bias0/gd=0
R22/Reb1/Bias0/gdP = 26.0
R22/Reb1/Bias0/od=0
R22/Reb1/Bias0/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb1/Bias0/og=0
R22/Reb1/Bias0/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb1/Bias0/ogSh=0
R22/Reb1/Bias0/rd=0
R22/Reb1/Bias0/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb1/Bias1/csGate=0
R22/Reb1/Bias1/csGateP=1.0
R22/Reb1/Bias1/gd=0
R22/Reb1/Bias1/gdP = 26.0
R22/Reb1/Bias1/od=0
R22/Reb1/Bias1/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb1/Bias1/og=0
R22/Reb1/Bias1/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb1/Bias1/ogSh=0
R22/Reb1/Bias1/rd=0
R22/Reb1/Bias1/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb1/Bias2/csGate=0
R22/Reb1/Bias2/csGateP=1.0
R22/Reb1/Bias2/gd=0
R22/Reb1/Bias2/gdP = 26.0
R22/Reb1/Bias2/od=0
R22/Reb1/Bias2/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb1/Bias2/og=0
R22/Reb1/Bias2/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb1/Bias2/ogSh=0
R22/Reb1/Bias2/rd=0
R22/Reb1/Bias2/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb1/DAC/csGate=[0,0,0]
R22/Reb1/DAC/pclkHigh=0
R22/Reb1/DAC/pclkHighP = '''+'{0:.2f}'.format(PclkH)+'''
R22/Reb1/DAC/pclkHighSh=0
R22/Reb1/DAC/pclkLow=0
R22/Reb1/DAC/pclkLowP = '''+'{0:.2f}'.format(PclkL)+'''
R22/Reb1/DAC/pclkLowSh=0
R22/Reb1/DAC/rgHigh=0
R22/Reb1/DAC/rgHighP = '''+'{0:.2f}'.format(RGH)+'''
R22/Reb1/DAC/rgHighSh=0
R22/Reb1/DAC/rgLow=0
R22/Reb1/DAC/rgLowP = '''+'{0:.2f}'.format(RGL)+'''
R22/Reb1/DAC/rgLowSh=0
R22/Reb1/DAC/sclkHigh=0
R22/Reb1/DAC/sclkHighP = '''+'{0:.2f}'.format(SclkH)+'''
R22/Reb1/DAC/sclkHighSh=0
R22/Reb1/DAC/sclkLow=0
R22/Reb1/DAC/sclkLowP = '''+'{0:.2f}'.format(SclkL)+'''
R22/Reb1/DAC/sclkLowSh=0
R22/Reb1/S10/ASPIC0/af1=0
R22/Reb1/S10/ASPIC0/clamp=0
R22/Reb1/S10/ASPIC0/gain=0
R22/Reb1/S10/ASPIC0/rc=14
R22/Reb1/S10/ASPIC0/tm=0
R22/Reb1/S10/ASPIC1/af1=0
R22/Reb1/S10/ASPIC1/clamp=0
R22/Reb1/S10/ASPIC1/gain=0
R22/Reb1/S10/ASPIC1/rc=14
R22/Reb1/S10/ASPIC1/tm=0
R22/Reb1/S11/ASPIC0/af1=0
R22/Reb1/S11/ASPIC0/clamp=0
R22/Reb1/S11/ASPIC0/gain=0
R22/Reb1/S11/ASPIC0/rc=14
R22/Reb1/S11/ASPIC0/tm=0
R22/Reb1/S11/ASPIC1/af1=0
R22/Reb1/S11/ASPIC1/clamp=0
R22/Reb1/S11/ASPIC1/gain=0
R22/Reb1/S11/ASPIC1/rc=14
R22/Reb1/S11/ASPIC1/tm=0
R22/Reb1/S12/ASPIC0/af1=0
R22/Reb1/S12/ASPIC0/clamp=0
R22/Reb1/S12/ASPIC0/gain=0
R22/Reb1/S12/ASPIC0/rc=14
R22/Reb1/S12/ASPIC0/tm=0
R22/Reb1/S12/ASPIC1/af1=0
R22/Reb1/S12/ASPIC1/clamp=0
R22/Reb1/S12/ASPIC1/gain=0
R22/Reb1/S12/ASPIC1/rc=14
R22/Reb1/S12/ASPIC1/tm=0
R22/Reb2/disableRTDHardwareCheck=true
R22/Reb2/serialNum=-1
R22/Reb2/Bias0/csGate=0
R22/Reb2/Bias0/csGateP=1.0
R22/Reb2/Bias0/gd=0
R22/Reb2/Bias0/gdP = 26.0
R22/Reb2/Bias0/od=0
R22/Reb2/Bias0/odP='''+'{0:.2f}'.format(OD)+'''
R22/Reb2/Bias0/og=0
R22/Reb2/Bias0/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb2/Bias0/ogSh=0
R22/Reb2/Bias0/rd=0
R22/Reb2/Bias0/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb2/Bias1/csGate=0
R22/Reb2/Bias1/csGateP=1.0
R22/Reb2/Bias1/gd=0
R22/Reb2/Bias1/gdP = 26.0
R22/Reb2/Bias1/od=0
R22/Reb2/Bias1/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb2/Bias1/og=0
R22/Reb2/Bias1/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb2/Bias1/ogSh=0
R22/Reb2/Bias1/rd=0
R22/Reb2/Bias1/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb2/Bias2/csGate=0
R22/Reb2/Bias2/csGateP=1.0
R22/Reb2/Bias2/gd=0
R22/Reb2/Bias2/gdP = 26.0
R22/Reb2/Bias2/od=0
R22/Reb2/Bias2/odP = '''+'{0:.2f}'.format(OD)+'''
R22/Reb2/Bias2/og=0
R22/Reb2/Bias2/ogP = '''+'{0:.2f}'.format(OG)+'''
R22/Reb2/Bias2/ogSh=0
R22/Reb2/Bias2/rd=0
R22/Reb2/Bias2/rdP = '''+'{0:.2f}'.format(RD)+'''
R22/Reb2/DAC/csGate=[0,0,0]
R22/Reb2/DAC/pclkHigh=0
R22/Reb2/DAC/pclkHighP = '''+'{0:.2f}'.format(PclkH)+'''
R22/Reb2/DAC/pclkHighSh=0
R22/Reb2/DAC/pclkLow=0
R22/Reb2/DAC/pclkLowP = '''+'{0:.2f}'.format(PclkL)+'''
R22/Reb2/DAC/pclkLowSh=0
R22/Reb2/DAC/rgHigh=0
R22/Reb2/DAC/rgHighP = '''+'{0:.2f}'.format(RGH)+'''
R22/Reb2/DAC/rgHighSh=0
R22/Reb2/DAC/rgLow=0
R22/Reb2/DAC/rgLowP = '''+'{0:.2f}'.format(RGL)+'''
R22/Reb2/DAC/rgLowSh=0
R21/Reb0/DAC/rgHighMax='''+'{0:.2f}'.format(RGH+1.0)+'''
R21/Reb0/DAC/rgHighMin='''+'{0:.2f}'.format(RGH-1.0)+'''
R21/Reb0/DAC/rgLowMax='''+'{0:.2f}'.format(RGL+1.0)+'''
R21/Reb0/DAC/rgLowMin='''+'{0:.2f}'.format(RGL-1.0)+'''
R21/Reb0/DAC/sclkHighMax='''+'{0:.2f}'.format(SclkH+1.0)+'''
R21/Reb0/DAC/sclkHighMin='''+'{0:.2f}'.format(SclkH-1.0)+'''
R21/Reb0/DAC/sclkLowMax='''+'{0:.2f}'.format(SclkL+1.0)+'''
R21/Reb0/DAC/sclkLowMin='''+'{0:.2f}'.format(SclkL-1.0)+''' 
R21/Reb1/Bias0/gdMax=27.0
R21/Reb1/Bias0/gdMin=25.0
R21/Reb1/Bias0/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R21/Reb1/Bias0/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R21/Reb1/Bias0/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R21/Reb1/Bias0/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R21/Reb1/Bias0/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R21/Reb1/Bias0/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R21/Reb1/Bias1/gdMax=27.0
R21/Reb1/Bias1/gdMin=25.0
R21/Reb1/Bias1/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R21/Reb1/Bias1/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R21/Reb1/Bias1/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R21/Reb1/Bias1/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R21/Reb1/Bias1/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R21/Reb1/Bias1/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R21/Reb1/Bias2/gdMax=27.0
R21/Reb1/Bias2/gdMin=25.0
R21/Reb1/Bias2/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R21/Reb1/Bias2/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R21/Reb1/Bias2/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R21/Reb1/Bias2/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R21/Reb1/Bias2/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R21/Reb1/Bias2/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R21/Reb1/DAC/pclkHighMax='''+'{0:.2f}'.format(PclkH+1.0)+'''
R21/Reb1/DAC/pclkHighMin='''+'{0:.2f}'.format(PclkH-1.0)+'''
R21/Reb1/DAC/pclkLowMax='''+'{0:.2f}'.format(PclkL+1.0)+'''
R21/Reb1/DAC/pclkLowMin='''+'{0:.2f}'.format(PclkL-1.0)+'''
R21/Reb1/DAC/rgHighMax='''+'{0:.2f}'.format(RGH+1.0)+'''
R21/Reb1/DAC/rgHighMin='''+'{0:.2f}'.format(RGH-1.0)+'''
R21/Reb1/DAC/rgLowMax='''+'{0:.2f}'.format(RGL+1.0)+'''
R21/Reb1/DAC/rgLowMin='''+'{0:.2f}'.format(RGL-1.0)+'''
R21/Reb1/DAC/sclkHighMax='''+'{0:.2f}'.format(SclkH+1.0)+'''
R21/Reb1/DAC/sclkHighMin='''+'{0:.2f}'.format(SclkH-1.0)+'''
R21/Reb1/DAC/sclkLowMax='''+'{0:.2f}'.format(SclkL+1.0)+'''
R21/Reb1/DAC/sclkLowMin='''+'{0:.2f}'.format(SclkL-1.0)+'''
R21/Reb2/Bias0/gdMax=27.0
R21/Reb2/Bias0/gdMin=25.0
R21/Reb2/Bias0/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R21/Reb2/Bias0/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R21/Reb2/Bias0/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R21/Reb2/Bias0/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R21/Reb2/Bias0/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R21/Reb2/Bias0/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R21/Reb2/Bias1/gdMax=27.0
R21/Reb2/Bias1/gdMin=25.0
R21/Reb2/Bias1/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R21/Reb2/Bias1/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R21/Reb2/Bias1/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R21/Reb2/Bias1/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R21/Reb2/Bias1/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R21/Reb2/Bias1/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R21/Reb2/Bias2/gdMax=27.0
R21/Reb2/Bias2/gdMin=25.0
R21/Reb2/Bias2/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R21/Reb2/Bias2/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R21/Reb2/Bias2/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R21/Reb2/Bias2/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R21/Reb2/Bias2/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R21/Reb2/Bias2/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R21/Reb2/DAC/pclkHighMax='''+'{0:.2f}'.format(PclkH+1.0)+'''
R21/Reb2/DAC/pclkHighMin='''+'{0:.2f}'.format(PclkH-1.0)+'''
R21/Reb2/DAC/pclkLowMax='''+'{0:.2f}'.format(PclkL+1.0)+'''
R21/Reb2/DAC/pclkLowMin='''+'{0:.2f}'.format(PclkL-1.0)+'''
R21/Reb2/DAC/rgHighMax='''+'{0:.2f}'.format(RGH+1.0)+'''
R21/Reb2/DAC/rgHighMin='''+'{0:.2f}'.format(RGH-1.0)+'''
R21/Reb2/DAC/rgLowMax='''+'{0:.2f}'.format(RGL+1.0)+'''
R21/Reb2/DAC/rgLowMin='''+'{0:.2f}'.format(RGL-1.0)+'''
R21/Reb2/DAC/sclkHighMax='''+'{0:.2f}'.format(SclkH+1.0)+'''
R21/Reb2/DAC/sclkHighMin='''+'{0:.2f}'.format(SclkH-1.0)+'''
R21/Reb2/DAC/sclkLowMax='''+'{0:.2f}'.format(SclkL+1.0)+'''
R21/Reb2/DAC/sclkLowMin='''+'{0:.2f}'.format(SclkL-1.0)+'''
R22/Reb0/Bias0/gdMax=27.0
R22/Reb0/Bias0/gdMin=25.0
R22/Reb0/Bias0/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb0/Bias0/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb0/Bias0/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb0/Bias0/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb0/Bias0/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb0/Bias0/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb0/Bias1/gdMax=27.0
R22/Reb0/Bias1/gdMin=25.0
R22/Reb0/Bias1/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb0/Bias1/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb0/Bias1/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb0/Bias1/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb0/Bias1/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb0/Bias1/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb0/Bias2/gdMax=27.0
R22/Reb0/Bias2/gdMin=25.0
R22/Reb0/Bias2/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb0/Bias2/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb0/Bias2/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb0/Bias2/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb0/Bias2/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb0/Bias2/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb0/DAC/pclkHighMax='''+'{0:.2f}'.format(PclkH+1.0)+'''
R22/Reb0/DAC/pclkHighMin='''+'{0:.2f}'.format(PclkH-1.0)+'''
R22/Reb0/DAC/pclkLowMax='''+'{0:.2f}'.format(PclkL+1.0)+'''
R22/Reb0/DAC/pclkLowMin='''+'{0:.2f}'.format(PclkL-1.0)+'''
R22/Reb0/DAC/rgHighMax='''+'{0:.2f}'.format(RGH+1.0)+'''
R22/Reb0/DAC/rgHighMin='''+'{0:.2f}'.format(RGH-1.0)+'''
R22/Reb0/DAC/rgLowMax='''+'{0:.2f}'.format(RGL+1.0)+'''
R22/Reb0/DAC/rgLowMin='''+'{0:.2f}'.format(RGL-1.0)+'''
R22/Reb0/DAC/sclkHighMax='''+'{0:.2f}'.format(SclkH+1.0)+'''
R22/Reb0/DAC/sclkHighMin='''+'{0:.2f}'.format(SclkH-1.0)+'''
R22/Reb0/DAC/sclkLowMax='''+'{0:.2f}'.format(SclkL+1.0)+'''
R22/Reb0/DAC/sclkLowMin='''+'{0:.2f}'.format(SclkL-1.0)+'''
R22/Reb1/Bias0/gdMax=27.0
R22/Reb1/Bias0/gdMin=25.0
R22/Reb1/Bias0/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb1/Bias0/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb1/Bias0/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb1/Bias0/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb1/Bias0/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb1/Bias0/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb1/Bias1/gdMax=27.0
R22/Reb1/Bias1/gdMin=25.0
R22/Reb1/Bias1/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb1/Bias1/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb1/Bias1/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb1/Bias1/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb1/Bias1/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb1/Bias1/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb1/Bias2/gdMax=27.0
R22/Reb1/Bias2/gdMin=25.0
R22/Reb1/Bias2/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb1/Bias2/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb1/Bias2/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb1/Bias2/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb1/Bias2/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb1/Bias2/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb1/DAC/pclkHighMax='''+'{0:.2f}'.format(PclkH+1.0)+'''
R22/Reb1/DAC/pclkHighMin='''+'{0:.2f}'.format(PclkH-1.0)+'''
R22/Reb1/DAC/pclkLowMax='''+'{0:.2f}'.format(PclkL+1.0)+'''
R22/Reb1/DAC/pclkLowMin='''+'{0:.2f}'.format(PclkL-1.0)+'''
R22/Reb1/DAC/rgHighMax='''+'{0:.2f}'.format(RGH+1.0)+'''
R22/Reb1/DAC/rgHighMin='''+'{0:.2f}'.format(RGH-1.0)+'''
R22/Reb1/DAC/rgLowMax='''+'{0:.2f}'.format(RGL+1.0)+'''
R22/Reb1/DAC/rgLowMin='''+'{0:.2f}'.format(RGL-1.0)+'''
R22/Reb1/DAC/sclkHighMax='''+'{0:.2f}'.format(SclkH+1.0)+'''
R22/Reb1/DAC/sclkHighMin='''+'{0:.2f}'.format(SclkH-1.0)+'''
R22/Reb1/DAC/sclkLowMax='''+'{0:.2f}'.format(SclkL+1.0)+'''
R22/Reb1/DAC/sclkLowMin='''+'{0:.2f}'.format(SclkL-1.0)+'''
R22/Reb2/Bias0/gdMax=27.0
R22/Reb2/Bias0/gdMin=25.0
R22/Reb2/Bias0/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb2/Bias0/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb2/Bias0/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb2/Bias0/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb2/Bias0/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb2/Bias0/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb2/Bias1/gdMax=27.0
R22/Reb2/Bias1/gdMin=25.0
R22/Reb2/Bias1/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb2/Bias1/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb2/Bias1/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb2/Bias1/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb2/Bias1/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb2/Bias1/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb2/Bias2/gdMax=27.0
R22/Reb2/Bias2/gdMin=25.0
R22/Reb2/Bias2/odMax='''+'{0:.2f}'.format(OD+1.0)+'''
R22/Reb2/Bias2/odMin='''+'{0:.2f}'.format(OD-1.0)+'''
R22/Reb2/Bias2/ogMax='''+'{0:.2f}'.format(OG+1.0)+'''
R22/Reb2/Bias2/ogMin='''+'{0:.2f}'.format(OG-1.0)+'''
R22/Reb2/Bias2/rdMax='''+'{0:.2f}'.format(RD+1.0)+'''
R22/Reb2/Bias2/rdMin='''+'{0:.2f}'.format(RD-1.0)+'''
R22/Reb2/DAC/pclkHighMax='''+'{0:.2f}'.format(PclkH+1.0)+'''
R22/Reb2/DAC/pclkHighMin='''+'{0:.2f}'.format(PclkH-1.0)+'''
R22/Reb2/DAC/pclkLowMax='''+'{0:.2f}'.format(PclkL+1.0)+'''
R22/Reb2/DAC/pclkLowMin='''+'{0:.2f}'.format(PclkL-1.0)+'''
R22/Reb2/DAC/rgHighMax='''+'{0:.2f}'.format(RGH+1.0)+'''
R22/Reb2/DAC/rgHighMin='''+'{0:.2f}'.format(RGH-1.0)+'''
R22/Reb2/DAC/rgLowMax='''+'{0:.2f}'.format(RGL+1.0)+'''
R22/Reb2/DAC/rgLowMin='''+'{0:.2f}'.format(RGL-1.0)+'''
R22/Reb2/DAC/sclkHighMax='''+'{0:.2f}'.format(SclkH+1.0)+'''
R22/Reb2/DAC/sclkHighMin='''+'{0:.2f}'.format(SclkH-1.0)+'''
R22/Reb2/DAC/sclkLowMax='''+'{0:.2f}'.format(SclkL+1.0)+'''
R22/Reb2/DAC/sclkLowMin='''+'{0:.2f}'.format(SclkL-1.0)

# %%
propfile = open(propertiesfile, 'w')
propfile.write(properties)       
propfile.close()

limfile = open(limitsfile, 'w')
limfile.write(limits)       
limfile.close()

# %%
properties='''R21/Reb0/Bias0/csGate = 0
R21/Reb0/Bias0/csGateP = 1.0
R21/Reb0/Bias0/gd = 0
R21/Reb0/Bias0/gdP = 26.0
R21/Reb0/Bias0/od = 0
R21/Reb0/Bias0/odP = 23.4
R21/Reb0/Bias0/og = 0
R21/Reb0/Bias0/ogP = -3.4
R21/Reb0/Bias0/ogSh = 0
R21/Reb0/Bias0/rd = 0
R21/Reb0/Bias0/rdP = 11.6
R21/Reb0/Bias1/csGate = 0
R21/Reb0/Bias1/csGateP = 1.0
R21/Reb0/Bias1/gd = 0
R21/Reb0/Bias1/gdP = 26.0
R21/Reb0/Bias1/od = 0
R21/Reb0/Bias1/odP = 23.4
R21/Reb0/Bias1/og = 0
R21/Reb0/Bias1/ogP = -3.4
R21/Reb0/Bias1/ogSh = 0
R21/Reb0/Bias1/rd = 0
R21/Reb0/Bias1/rdP = 11.6
R21/Reb0/Bias2/csGate = 0
R21/Reb0/Bias2/csGateP = 1.0
R21/Reb0/Bias2/gd = 0
R21/Reb0/Bias2/gdP = 26.0
R21/Reb0/Bias2/od = 0
R21/Reb0/Bias2/odP = 23.4
R21/Reb0/Bias2/og = 0
R21/Reb0/Bias2/ogP = -3.4
R21/Reb0/Bias2/ogSh = 0
R21/Reb0/Bias2/rd = 0
R21/Reb0/Bias2/rdP = 11.6
R21/Reb0/DAC/csGate = [0,0,0]
R21/Reb0/DAC/pclkHigh = 0
R21/Reb0/DAC/pclkHighP = 3.3
R21/Reb0/DAC/pclkHighSh = 0
R21/Reb0/DAC/pclkLow = 0
R21/Reb0/DAC/pclkLowP = -5.9
R21/Reb0/DAC/pclkLowSh = 0
R21/Reb0/DAC/rgHigh = 0
R21/Reb0/DAC/rgHighP = 6.1
R21/Reb0/DAC/rgHighSh = 0
R21/Reb0/DAC/rgLow = 0
R21/Reb0/DAC/rgLowP = -4.0
R21/Reb0/DAC/rgLowSh = 0
R21/Reb0/DAC/sclkHigh = 0
R21/Reb0/DAC/sclkHighP = 3.9
R21/Reb0/DAC/sclkHighSh = 0
R21/Reb0/DAC/sclkLow = 0
R21/Reb0/DAC/sclkLowP = -5.4
R21/Reb0/DAC/sclkLowSh = 0
R21/Reb0/S00/ASPIC0/af1 = 0
R21/Reb0/S00/ASPIC0/clamp = 0
R21/Reb0/S00/ASPIC0/gain = 0
R21/Reb0/S00/ASPIC0/rc = 14
R21/Reb0/S00/ASPIC0/tm = 0
R21/Reb0/S00/ASPIC1/af1 = 0
R21/Reb0/S00/ASPIC1/clamp = 0
R21/Reb0/S00/ASPIC1/gain = 0
R21/Reb0/S00/ASPIC1/rc = 14
R21/Reb0/S00/ASPIC1/tm = 0
R21/Reb0/S01/ASPIC0/af1 = 0
R21/Reb0/S01/ASPIC0/clamp = 0
R21/Reb0/S01/ASPIC0/gain = 0
R21/Reb0/S01/ASPIC0/rc = 14
R21/Reb0/S01/ASPIC0/tm = 0
R21/Reb0/S01/ASPIC1/af1 = 0
R21/Reb0/S01/ASPIC1/clamp = 0
R21/Reb0/S01/ASPIC1/gain = 0
R21/Reb0/S01/ASPIC1/rc = 14
R21/Reb0/S01/ASPIC1/tm = 0
R21/Reb0/S02/ASPIC0/af1 = 0
R21/Reb0/S02/ASPIC0/clamp = 0
R21/Reb0/S02/ASPIC0/gain = 0
R21/Reb0/S02/ASPIC0/rc = 14
R21/Reb0/S02/ASPIC0/tm = 0
R21/Reb0/S02/ASPIC1/af1 = 0
R21/Reb0/S02/ASPIC1/clamp = 0
R21/Reb0/S02/ASPIC1/gain = 0
R21/Reb0/S02/ASPIC1/rc = 14
R21/Reb0/S02/ASPIC1/tm = 0
R21/Reb0/disableRTDHardwareCheck = true
R21/Reb0/serialNum = -1
R21/Reb0/useScienceCCD = false
R21/Reb1/Bias0/csGate = 0
R21/Reb1/Bias0/csGateP = 1.0
R21/Reb1/Bias0/gd = 0
R21/Reb1/Bias0/gdP = 26.0
R21/Reb1/Bias0/od = 0
R21/Reb1/Bias0/odP = 23.4
R21/Reb1/Bias0/og = 0
R21/Reb1/Bias0/ogP = -3.4
R21/Reb1/Bias0/ogSh = 0
R21/Reb1/Bias0/rd = 0
R21/Reb1/Bias0/rdP = 11.6
R21/Reb1/Bias1/csGate = 0
R21/Reb1/Bias1/csGateP = 1.0
R21/Reb1/Bias1/gd = 0
R21/Reb1/Bias1/gdP = 26.0
R21/Reb1/Bias1/od = 0
R21/Reb1/Bias1/odP = 23.4
R21/Reb1/Bias1/og = 0
R21/Reb1/Bias1/ogP = -3.4
R21/Reb1/Bias1/ogSh = 0
R21/Reb1/Bias1/rd = 0
R21/Reb1/Bias1/rdP = 11.6
R21/Reb1/Bias2/csGate = 0
R21/Reb1/Bias2/csGateP = 1.0
R21/Reb1/Bias2/gd = 0
R21/Reb1/Bias2/gdP = 26.0
R21/Reb1/Bias2/od = 0
R21/Reb1/Bias2/odP = 23.4
R21/Reb1/Bias2/og = 0
R21/Reb1/Bias2/ogP = -3.4
R21/Reb1/Bias2/ogSh = 0
R21/Reb1/Bias2/rd = 0
R21/Reb1/Bias2/rdP = 11.6
R21/Reb1/DAC/csGate = [0,0,0]
R21/Reb1/DAC/pclkHigh = 0
R21/Reb1/DAC/pclkHighP = 3.3
R21/Reb1/DAC/pclkHighSh = 0
R21/Reb1/DAC/pclkLow = 0
R21/Reb1/DAC/pclkLowP = -6.0
R21/Reb1/DAC/pclkLowSh = 0
R21/Reb1/DAC/rgHigh = 0
R21/Reb1/DAC/rgHighP = 6.1
R21/Reb1/DAC/rgHighSh = 0
R21/Reb1/DAC/rgLow = 0
R21/Reb1/DAC/rgLowP = -4.0
R21/Reb1/DAC/rgLowSh = 0
R21/Reb1/DAC/sclkHigh = 0
R21/Reb1/DAC/sclkHighP = 3.9
R21/Reb1/DAC/sclkHighSh = 0
R21/Reb1/DAC/sclkLow = 0
R21/Reb1/DAC/sclkLowP = -5.4
R21/Reb1/DAC/sclkLowSh = 0
R21/Reb1/S10/ASPIC0/af1 = 0
R21/Reb1/S10/ASPIC0/clamp = 0
R21/Reb1/S10/ASPIC0/gain = 0
R21/Reb1/S10/ASPIC0/rc = 14
R21/Reb1/S10/ASPIC0/tm = 0
R21/Reb1/S10/ASPIC1/af1 = 0
R21/Reb1/S10/ASPIC1/clamp = 0
R21/Reb1/S10/ASPIC1/gain = 0
R21/Reb1/S10/ASPIC1/rc = 14
R21/Reb1/S10/ASPIC1/tm = 0
R21/Reb1/S11/ASPIC0/af1 = 0
R21/Reb1/S11/ASPIC0/clamp = 0
R21/Reb1/S11/ASPIC0/gain = 0
R21/Reb1/S11/ASPIC0/rc = 14
R21/Reb1/S11/ASPIC0/tm = 0
R21/Reb1/S11/ASPIC1/af1 = 0
R21/Reb1/S11/ASPIC1/clamp = 0
R21/Reb1/S11/ASPIC1/gain = 0
R21/Reb1/S11/ASPIC1/rc = 14
R21/Reb1/S11/ASPIC1/tm = 0
R21/Reb1/S12/ASPIC0/af1 = 0
R21/Reb1/S12/ASPIC0/clamp = 0
R21/Reb1/S12/ASPIC0/gain = 0
R21/Reb1/S12/ASPIC0/rc = 14
R21/Reb1/S12/ASPIC0/tm = 0
R21/Reb1/S12/ASPIC1/af1 = 0
R21/Reb1/S12/ASPIC1/clamp = 0
R21/Reb1/S12/ASPIC1/gain = 0
R21/Reb1/S12/ASPIC1/rc = 14
R21/Reb1/S12/ASPIC1/tm = 0
R21/Reb1/disableRTDHardwareCheck = true
R21/Reb1/serialNum = -1
R21/Reb1/useScienceCCD = false
R21/Reb2/Bias0/csGate = 0
R21/Reb2/Bias0/csGateP = 1.0
R21/Reb2/Bias0/gd = 0
R21/Reb2/Bias0/gdP = 26.0
R21/Reb2/Bias0/od = 0
R21/Reb2/Bias0/odP = 23.4
R21/Reb2/Bias0/og = 0
R21/Reb2/Bias0/ogP = -3.4
R21/Reb2/Bias0/ogSh = 0
R21/Reb2/Bias0/rd = 0
R21/Reb2/Bias0/rdP = 11.6
R21/Reb2/Bias1/csGate = 0
R21/Reb2/Bias1/csGateP = 1.0
R21/Reb2/Bias1/gd = 0
R21/Reb2/Bias1/gdP = 26.0
R21/Reb2/Bias1/od = 0
R21/Reb2/Bias1/odP = 23.4
R21/Reb2/Bias1/og = 0
R21/Reb2/Bias1/ogP = -3.4
R21/Reb2/Bias1/ogSh = 0
R21/Reb2/Bias1/rd = 0
R21/Reb2/Bias1/rdP = 11.6
R21/Reb2/Bias2/csGate = 0
R21/Reb2/Bias2/csGateP = 1.0
R21/Reb2/Bias2/gd = 0
R21/Reb2/Bias2/gdP = 26.0
R21/Reb2/Bias2/od = 0
R21/Reb2/Bias2/odP = 23.4
R21/Reb2/Bias2/og = 0
R21/Reb2/Bias2/ogP = -3.4
R21/Reb2/Bias2/ogSh = 0
R21/Reb2/Bias2/rd = 0
R21/Reb2/Bias2/rdP = 11.6
R21/Reb2/DAC/csGate = [0,0,0]
R21/Reb2/DAC/pclkHigh = 0
R21/Reb2/DAC/pclkHighP = 3.3
R21/Reb2/DAC/pclkHighSh = 0
R21/Reb2/DAC/pclkLow = 0
R21/Reb2/DAC/pclkLowP = -6.0
R21/Reb2/DAC/pclkLowSh = 0
R21/Reb2/DAC/rgHigh = 0
R21/Reb2/DAC/rgHighP = 6.1
R21/Reb2/DAC/rgHighSh = 0
R21/Reb2/DAC/rgLow = 0
R21/Reb2/DAC/rgLowP = -4.0
R21/Reb2/DAC/rgLowSh = 0
R21/Reb2/DAC/sclkHigh = 0
R21/Reb2/DAC/sclkHighP = 3.9
R21/Reb2/DAC/sclkHighSh = 0
R21/Reb2/DAC/sclkLow = 0
R21/Reb2/DAC/sclkLowP = -5.4
R21/Reb2/DAC/sclkLowSh = 0
R21/Reb2/S20/ASPIC0/af1 = 0
R21/Reb2/S20/ASPIC0/clamp = 0
R21/Reb2/S20/ASPIC0/gain = 0
R21/Reb2/S20/ASPIC0/rc = 14
R21/Reb2/S20/ASPIC0/tm = 0
R21/Reb2/S20/ASPIC1/af1 = 0
R21/Reb2/S20/ASPIC1/clamp = 0
R21/Reb2/S20/ASPIC1/gain = 0
R21/Reb2/S20/ASPIC1/rc = 14
R21/Reb2/S20/ASPIC1/tm = 0
R21/Reb2/S21/ASPIC0/af1 = 0
R21/Reb2/S21/ASPIC0/clamp = 0
R21/Reb2/S21/ASPIC0/gain = 0
R21/Reb2/S21/ASPIC0/rc = 14
R21/Reb2/S21/ASPIC0/tm = 0
R21/Reb2/S21/ASPIC1/af1 = 0
R21/Reb2/S21/ASPIC1/clamp = 0
R21/Reb2/S21/ASPIC1/gain = 0
R21/Reb2/S21/ASPIC1/rc = 14
R21/Reb2/S21/ASPIC1/tm = 0
R21/Reb2/S22/ASPIC0/af1 = 0
R21/Reb2/S22/ASPIC0/clamp = 0
R21/Reb2/S22/ASPIC0/gain = 0
R21/Reb2/S22/ASPIC0/rc = 14
R21/Reb2/S22/ASPIC0/tm = 0
R21/Reb2/S22/ASPIC1/af1 = 0
R21/Reb2/S22/ASPIC1/clamp = 0
R21/Reb2/S22/ASPIC1/gain = 0
R21/Reb2/S22/ASPIC1/rc = 14
R21/Reb2/S22/ASPIC1/tm = 0
R21/Reb2/disableRTDHardwareCheck = true
R21/Reb2/serialNum = -1
R21/Reb2/useScienceCCD = false
R22/Reb0/disableRTDHardwareCheck = true
R22/Reb0/serialNum=-1
R22/Reb0/Bias0/csGate=0
R22/Reb0/Bias0/csGateP=1.0
R22/Reb0/Bias0/gd=0
R22/Reb0/Bias0/gdP=20.0
R22/Reb0/Bias0/od=0
R22/Reb0/Bias0/odP=26.9
R22/Reb0/Bias0/og=0
R22/Reb0/Bias0/ogP=-2.0
R22/Reb0/Bias0/ogSh=0
R22/Reb0/Bias0/rd=0
R22/Reb0/Bias0/rdP=13.0
R22/Reb0/Bias1/csGate=0
R22/Reb0/Bias1/csGateP=1.0
R22/Reb0/Bias1/gd=0
R22/Reb0/Bias1/gdP=20.0
R22/Reb0/Bias1/od=0
R22/Reb0/Bias1/odP=26.9
R22/Reb0/Bias1/og=0
R22/Reb0/Bias1/ogP=-2.0
R22/Reb0/Bias1/ogSh=0
R22/Reb0/Bias1/rd=0
R22/Reb0/Bias1/rdP=13.0
R22/Reb0/Bias2/csGate=0
R22/Reb0/Bias2/csGateP=1.0
R22/Reb0/Bias2/gd=0
R22/Reb0/Bias2/gdP=20.0
R22/Reb0/Bias2/od=0
R22/Reb0/Bias2/odP=26.9
R22/Reb0/Bias2/og=0
R22/Reb0/Bias2/ogP=-2.0
R22/Reb0/Bias2/ogSh=0
R22/Reb0/Bias2/rd=0
R22/Reb0/Bias2/rdP=13.0
R22/Reb0/DAC/csGate=[0,0,0]
R22/Reb0/DAC/pclkHigh=0
R22/Reb0/DAC/pclkHighP=2.0
R22/Reb0/DAC/pclkHighSh=0
R22/Reb0/DAC/pclkLow=0
R22/Reb0/DAC/pclkLowP=-8.0
R22/Reb0/DAC/pclkLowSh=0
R22/Reb0/DAC/rgHigh=0
R22/Reb0/DAC/rgHighP=8.0
R22/Reb0/DAC/rgHighSh=0
R22/Reb0/DAC/rgLow=0
R22/Reb0/DAC/rgLowP=-2.0
R22/Reb0/DAC/rgLowSh=0
R22/Reb0/DAC/sclkHigh=0
R22/Reb0/DAC/sclkHighP=5.0
R22/Reb0/DAC/sclkHighSh=0
R22/Reb0/DAC/sclkLow=0
